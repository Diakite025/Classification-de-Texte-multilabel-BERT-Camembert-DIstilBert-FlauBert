# %% [markdown]
# # Entrainement

# %%
import torch

# %%
import entrainementDuModeleDistilBert,evaluation_modele

# %%
entrainementDuModeleDistilBert.main()
# Out:
#  ################################# Importation des données #####################################
#
# Train: (434779, 55), Valid: (216876, 55)
#
#  ################################### Entrainement du modèle ##############################
#
# Epoch 1/5
# ...
# 100%|██████████| 6778/6778 [14:46<00:00,  7.64it/s]
# Temps d'exécution: 94.97947846253713 min
#
# train_loss=0.0576, val_loss=0.0218 train_acc=0.9860, val_acc=0.9940
# Epoch 2/5
# ...
# 100%|██████████| 6778/6778 [26:27<00:00,  4.27it/s]
# Temps d'exécution: 159.36268716653188 min
#
# train_loss=0.0125, val_loss=0.0167 train_acc=0.9965, val_acc=0.9951
# Epoch 3/5
# ...
# 100%|██████████| 6778/6778 [27:09<00:00,  4.16it/s]
# Temps d'exécution: 182.31951718330384 min
#
# train_loss=0.0087, val_loss=0.0155 train_acc=0.9974, val_acc=0.9956
# Epoch 4/5
# ...
# 100%|██████████| 6778/6778 [26:25<00:00,  4.28it/s]
# Temps d'exécution: 179.77978492975234 min
#
# train_loss=0.0066, val_loss=0.0139 train_acc=0.9980, val_acc=0.9960
# Epoch 5/5
# ...

# %% [markdown]
# # Evaluation

# %%
evaluation_modele.main()
# Out:
#  ################################# Importation des données #####################################
# 100%|██████████| 6781/6781 [21:55<00:00,  5.16it/s]
# /home/mariam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                                        precision    recall  f1-score   support
#
#                                        building_works       0.89      0.34      0.49      2305
#                         studies_consulting_assistance       0.96      0.80      0.88     26553
#                        transport_and_related_services       0.94      0.88      0.91      5486
#                      financial_and_insurance_services       0.71      0.80      0.75      1570
# ...

# %%
import importEtInsert_data
df_test=importEtInsert_data.Importation_dataFrame("df_test_en")

evaluation_modele.main(df=df_test,path="BestModel/model_en_V2.pth")
# Out:
#  ################################# Importation des données #####################################
# 100%|██████████| 6781/6781 [16:28<00:00,  6.86it/s]
# /home/mariam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                                        precision    recall  f1-score   support
#
#                                        building_works       0.68      0.30      0.42      2305
#                         studies_consulting_assistance       0.97      0.51      0.67     26553
#                        transport_and_related_services       0.84      0.70      0.76      5486
#                      financial_and_insurance_services       0.68      0.71      0.69      1570
# ...

# %% [markdown]
# # Prédiction

# %%
import  predictionModel

predictionModel.main(texte="""
                     Rechargers Battery chargers Electricity supplies Electrical installation work Electricity supply installations
                     """)
# Out:
# Texte      :
#                      Rechargers Battery chargers Electricity supplies Electrical installation work Electricity supply installations
#
# Prediction :  ['electrical_equipment']
# ['electrical_equipment']
