# %% [markdown]
# # Entrainement du modèle

# %%
import entrainementDuModelFlauBert

entrainementDuModelFlauBert.main()
# Out:
#  ################################# Importation des données #####################################
#
# Train: (325655, 54), Valid: (100281, 54)
#
#  ################################### Entrainement du modèle ##############################
#
# Epoch 1/5
# ...
# 100%|██████████| 3134/3134 [11:11<00:00,  4.67it/s]
# Temps d'exécution: 141.27196488777795 min
#
# train_loss=0.0735, val_loss=0.0216 train_acc=0.9823, val_acc=0.9939
# Epoch 2/5
# ...
# 100%|██████████| 3134/3134 [11:09<00:00,  4.68it/s]
# Temps d'exécution: 119.82547200918198 min
#
# train_loss=0.0206, val_loss=0.0145 train_acc=0.9940, val_acc=0.9958
# Epoch 3/5
# ...
# 100%|██████████| 3134/3134 [11:03<00:00,  4.72it/s]
# Temps d'exécution: 123.32524819374085 min
#
# train_loss=0.0144, val_loss=0.0129 train_acc=0.9958, val_acc=0.9961
# Epoch 4/5
# ...
# 100%|██████████| 3134/3134 [10:21<00:00,  5.04it/s]
# Temps d'exécution: 117.45214533011118 min
#
# train_loss=0.0113, val_loss=0.0124 train_acc=0.9967, val_acc=0.9963
# Epoch 5/5
# ...

# %% [markdown]
# # Evaluation du modèle

# %%
import evaluation_modele

evaluation_modele.main()
# Out:
#  ################################# Importation des données #####################################
# 100%|██████████| 3134/3134 [10:57<00:00,  4.77it/s]
#                                                        precision    recall  f1-score   support
#
#                                        building_works       0.98      0.92      0.95     18585
#                         studies_consulting_assistance       0.99      0.92      0.95     14928
#                        transport_and_related_services       0.98      0.84      0.90     10341
#                      financial_and_insurance_services       0.98      0.98      0.98      4075
#                                              sewerage       0.95      0.90      0.93      5187
#         car_industry_products_and_transport_equipment       0.95      0.94      0.95      4147
#                  real_estate_missions_and_inspections       0.91      0.95      0.93      3892
# ...

# %% [markdown]
# # Prédiction du modèle

# %%
import predictionModel
predictionModel.main(texte=""" Musee d amiens - programmation et mise en oeuvre des expositions 
                     temporaires 2023 Musee d amiens - programmation et mise en oeuvre des expositions temporaires 2023
Musee d Amiens - Programmation et mise en oeuvre des expositions temporaires 2023
Transport des oeuvres pour l'exposition Vingt mille lieues sous les mers l'exposition amiénoise
Soclage temporaire des oeuvres
Mise en état de présentation des oeuvres pour l'exposition Vingt mille lieues sous les mers : l'exposition amiénoise
Prestation d'assurances des expôts empruntés pour l'exposition Vingt mille lieues sous les mers :l'exposition amiénoise
Edition d'une publication, type catalogue d'exposition pour la Somme des préhistoires
Assurance
Edition
Oeuvre d'art
Transport
Equipement muséographique""")
# Out:
# Texte      :   Musee d amiens - programmation et mise en oeuvre des expositions
#                      temporaires 2023 Musee d amiens - programmation et mise en oeuvre des expositions temporaires 2023
# Musee d Amiens - Programmation et mise en oeuvre des expositions temporaires 2023
# Transport des oeuvres pour l'exposition Vingt mille lieues sous les mers l'exposition amiénoise
# Soclage temporaire des oeuvres
# Mise en état de présentation des oeuvres pour l'exposition Vingt mille lieues sous les mers : l'exposition amiénoise
# Prestation d'assurances des expôts empruntés pour l'exposition Vingt mille lieues sous les mers :l'exposition amiénoise
# Edition d'une publication, type catalogue d'exposition pour la Somme des préhistoires
# Assurance
# Edition
# Oeuvre d'art
# Transport
# Equipement muséographique
# Prediction :  ['transport_and_related_services', 'recreational_cultural_and_sports_services', 'radio_television_and_communication_equipment']
# ...
